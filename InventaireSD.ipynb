# %% [markdown]
# # Configuration à reproduire pour Drone ? :
# ifconfig
#
# ##### Pour ouvrir une fénêtre de configuration avancée et étendre l'installation à toute la mémoire de la carte SD :
# sudo raspi-config
#
#
# sudo apt-get update
#
# sudo apt-get upgrade
#
# sudo python3 -m pip install --upgrade pip
#
# sudo python3 -m pip install jupyter
#
# sudo apt-get install gparted
#
# ### Installation pour Drone :
# selon https://pyparrot.readthedocs.io/en/latest/installation.html#software-requirements
# sudo pip install untangle
#
# sudo pip install zeroconf
#
# sudo apt-get install bluetooth
#
# sudo apt-get install bluez
#
# sudo apt-get install python-bluez
#
# sudo apt-get install python-pip libglib2.0-dev
#
# sudo pip install bluepy
#
# sudo apt-get update
#
# sudo apt-get upgrade
#
# sudo pip install pyparrot

# %% [markdown]
# # Inventaire des cartes SD :
#
# |  **Numéro**  | **Taille** | **Marque** | **Machine** | **Distribution** | **Mot de passe** | **Usage** |
# |:------------:|:----------:|:----------:|:-----------:|:----------------:|:----------------:|:----------------:|
# |     0        |      2     |Transcend|---- |vide    | | |
# |     1        |      8     |Transcend|---- |PB A revoir    | | |
# |     2        |      8     |Transcend|EV3  |EV3dev MicroPython| | |
# |     3        |      8     |sans     |Rpi_ | 2019-06-20-raspbian-buster    | | |
# |     4        |      8     |SanDisk  |Rpi_ | 2019-06-20-raspbian-buster    | | |
# |     5        |      8     |SanDisk  |Rpi__|2024-07-04-raspios-bookworm-arm64-lite = 22| bac |s2int|
# |     8        |     16     |Samsung  |Rpi_|2019-06-20-raspbian-buster-full | | |
# |     9        |     16     |Kingston |Rpi_|2019-06-20-raspbian-buster-full | | |
# |     10       |     16     |Kingston |EV3|EV3dev MicroPython v2.0.0| | |
# |     11       |     16     |Kingston |EV3|EV3dev MicroPython v2.0.0| | |
# |     12       |     16     |Kingston |EV3|EV3dev MicroPython v2.0.0| | |
# |     13       |     16     |Kingston |Rpi zero WH|QuickPi| | |
# |     14       |     16     |Kingston |STEMlab14|RedPitaya Beta | | |
# |     15 A     |     16     |Kingston |EV3|EV3dev MicroPython v2.0.0| | |
# |     16       |     16     |Kingston |BrickPi|BrickMan | | |
# |     17       |     16     |SanDisk|EV3|EV3dev MicroPython v2.0.0| | |
# |     18       |     16     |SanDisk|Rpi_|2024-07-04-raspios-bookworm-arm64 = 25| bac |s2int |
# |     19       |     16     |SanDisk|Rpi400|2024-07-04-raspios-bookworm-arm64-full| bac |s2int |
# |     20       |     16     |SanDisk|Rpi__|2024-07-04-raspios-bookworm-arm64 = 18,21,23| bac |s2int |
# |     21       |     16     |SanDisk|Rpi__|2024-07-04-raspios-bookworm-arm64 = 18,20,23| bac |s2int |
# |     22       |     8      |SanDisk|Rpi__|2024-07-04-raspios-bookworm-arm64-lite = 5| bac |s2int|
# |     23       |     16     |Kingston|Rpi__|2024-07-04-raspios-bookworm-arm64 = 18,20,21| bac |s2int |
# |     24       |     16     |Kingston|STEMLab 125-14|RedPitaya OS2.00-23 beta|  | |
# |     25       |     16     |SanDisk|Rpi400|2024-07-04-raspios-bookworm-arm64-full = 19| bac |s2int |
# |     26       |     8      |SanDisk|Rpi3B+|haos_rpi3-64-11.1|  |Avent|
# |     27       |     16     |Samsung|EV3|LEGO EV3 MicroPython v2.0.0 | | |
# |     28 B     |     16     |Kingston |EV3|LEGO EV3 MicroPython v2.0.0 | | |
# |     29       |     16     |Kingston ||Stockage| | |
# |     ??       |     16     |Kingston |Rpi__|haos_rpi3-64-11.1|  ||
#
#
# STEMLab 125-10 RedPitaya OS2.00-23 beta

# %% [markdown]
# Lakka est une distribution Linux qui va vous permettre de transformer votre Raspberry Pi en une vraie console de jeu :
# - https://www.raspberrypi-france.fr/installer-lakka-raspberry-pi/

# %% [markdown]
# - https://projects.raspberrypi.org/en/projects/whoopi-cushion/2
