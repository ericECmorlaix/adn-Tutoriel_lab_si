# %% [markdown]
# ## SQLite3
#
# ### sqlite3-00-creer-un-db
#
# <iframe src="//video.toutatice.fr/video/41530-tuto-sqlite3-00-creer-un-db/?is_iframe=true" size="240" width="640" height="360" style="padding: 0; margin: 0; border:0" allowfullscreen ></iframe>
#
# ### sqlite3-01-create-insert-commit
#
# <iframe src="//video.toutatice.fr/video/41531-tuto-sqlite3-01-create-insert-commit/?is_iframe=true" size="240" width="640" height="360" style="padding: 0; margin: 0; border:0" allowfullscreen ></iframe>
#
# ### sqlite3-02-fetch
#
# <iframe src="//video.toutatice.fr/video/41532-tuto-sqlite3-02-fetch/?is_iframe=true" size="240" width="640" height="360" style="padding: 0; margin: 0; border:0" allowfullscreen ></iframe>
#
# ### sqlite3-03-fichier-sql
#
# <iframe src="//video.toutatice.fr/video/41533-tuto-sqlite3-03-fichier-sql/?is_iframe=true" size="240" width="640" height="360" style="padding: 0; margin: 0; border:0" allowfullscreen ></iframe>
#
# ### sqlite3-04-resultat
#
# <iframe src="//video.toutatice.fr/video/41534-tuto-sqlite3-04-resultat/?is_iframe=true" size="240" width="640" height="360" style="padding: 0; margin: 0; border:0" allowfullscreen ></iframe>
