# %% [markdown]
# - [Dear PyGUI](#dear-pygui)
# - [FLET](#flet)
#
#
#
# ## [Dear PyGUI](https://dearpygui.readthedocs.io/en/latest/index.html)
#
# ### dpg-000-config
#
# <iframe src="//video.toutatice.fr/video/41494-tuto-dpg-000-config/?is_iframe=true" size="240" width="640" height="360" style="padding: 0; margin: 0; border:0" allowfullscreen ></iframe>
#
# ### dpg-001-fenetre
#
# <iframe src="//video.toutatice.fr/video/41495-tuto-dpg-001-fenetre/?is_iframe=true" size="240" width="640" height="360" style="padding: 0; margin: 0; border:0" allowfullscreen ></iframe>
#
# ### dpg-002-le-gui
#
# <iframe src="//video.toutatice.fr/video/41496-tuto-dpg-002-le-gui/?is_iframe=true" size="240" width="640" height="360" style="padding: 0; margin: 0; border:0" allowfullscreen ></iframe>
#
# ### dpg-003-interfacage
#
# <iframe src="//video.toutatice.fr/video/41498-tuto-dpg-003-interfacage/?is_iframe=true" size="240" width="640" height="360" style="padding: 0; margin: 0; border:0" allowfullscreen ></iframe>
#
#
# ## [FLET](https://www.pythonguis.com/tutorials/getting-started-flet/)
#
#
# ### flet-000-config
#
# <iframe src="//video.toutatice.fr/video/41507-tuto-flet-000-config/?is_iframe=true" size="240" width="640" height="360" style="padding: 0; margin: 0; border:0" allowfullscreen ></iframe>
#
# ### flet-001-fenetre
#
# <iframe src="//video.toutatice.fr/video/41509-tuto-flet-001-fenetre/?is_iframe=true" size="240" width="640" height="360" style="padding: 0; margin: 0; border:0" allowfullscreen ></iframe>
#
# ### flet-002-gui
#
# <iframe src="//video.toutatice.fr/video/41510-tuto-flet-002-gui/?is_iframe=true" size="240" width="640" height="360" style="padding: 0; margin: 0; border:0" allowfullscreen ></iframe>
#
# ### flet-003-interfacage
#
# <iframe src="//video.toutatice.fr/video/41511-tuto-flet-003-interfacage/?is_iframe=true" size="240" width="640" height="360" style="padding: 0; margin: 0; border:0" allowfullscreen ></iframe>
#
# ### flet 004-flet-pack
#
# <iframe src="//video.toutatice.fr/video/41512-tuto-flet-004-flet-pack/?is_iframe=true" size="240" width="640" height="360" style="padding: 0; margin: 0; border:0" allowfullscreen ></iframe>
#
# ### flet-005-web-view
#
# <iframe src="//video.toutatice.fr/video/41513-tuto-flet-005-web-view/?is_iframe=true" size="240" width="640" height="360" style="padding: 0; margin: 0; border:0" allowfullscreen ></iframe>
